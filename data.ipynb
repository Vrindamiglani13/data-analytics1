# %%
import pandas as pd
import numpy as np
import time
import calendar

# %%
df=pd.read_excel("C:/Users/Admin/Desktop/Data Analyst Assignment 2.xlsx")

# %%
df.head()
# Out:
#     SKU  2019-08-01 00:00:00  2019-08-02 00:00:00  2019-08-03 00:00:00  \
# 0  2527                 1551                 1613                 1613
# 1  3042                 2240                 2330                 2423
# 2  3086                  891                  909                  936
# 3  3155                 1628                 1628                 1563
# 4  3166                  369                  354                  343
#
#    2019-08-04 00:00:00  2019-08-05 00:00:00  2019-08-06 00:00:00  \
# 0                 1532                 1517                 1441
# 1                 2350                 2374                 2398
# 2                  889                  880                  906
# 3                 1532                 1563                 1563
# 4                  340                  330                  337
#
#    2019-08-07 00:00:00  2019-08-08 00:00:00  2019-08-09 00:00:00  ...  \
# 0                 1383                 1424                 1381  ...
# ...

# %%
result=df.columns
result
# Out:
# Index([              'SKU', 2019-08-01 00:00:00, 2019-08-02 00:00:00,
#        2019-08-03 00:00:00, 2019-08-04 00:00:00, 2019-08-05 00:00:00,
#        2019-08-06 00:00:00, 2019-08-07 00:00:00, 2019-08-08 00:00:00,
#        2019-08-09 00:00:00,
#        ...
#        2020-07-22 00:00:00, 2020-07-23 00:00:00, 2020-07-24 00:00:00,
#        2020-07-25 00:00:00, 2020-07-26 00:00:00, 2020-07-27 00:00:00,
#        2020-07-28 00:00:00, 2020-07-29 00:00:00, 2020-07-30 00:00:00,
#        2020-07-31 00:00:00],
#       dtype='object', length=367)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-9553edc23db5> in <module>
# ----> 1 df['month'] = result.dt.month
#
# AttributeError: 'Index' object has no attribute 'dt'
